# %% [markdown]
# # Coffee Quality Measurement

# %% [markdown]
# ## Description

# %% [markdown]
# Imma do coffe stuff

# %% [markdown]
# ## Objectives

# %% [markdown]
# Be the best coffee there ever was

# %% [markdown]
# ## Code

# %% [markdown]
# ### Imports

# %% [markdown]
# Here we import our dependencies

# %%
import os
import pandas as pd
import zipfile
import urllib.request

# %% [markdown]
# ### Import Dataset

# %% [markdown]
# Download dataset

# %%
#dataset_route = os.path.join("res","df_arabica_clean.csv")
#coffeeDataset = pd.read_csv(dataset_route, sep=",", index_col=0)
dataset_url = "https://www.kaggle.com/api/v1/datasets/download/fatihb/coffee-quality-data-cqi"
full_route = os.path.join("res", "dataset.zip")
urllib.request.urlretrieve(dataset_url, full_route)

# %% [markdown]
# Unzip file

# %%
file_route = os.path.join("res")
with
