# %% [markdown]
# # Coffee Quality Measurement

# %% [markdown]
# ## Description

# %% [markdown]
# Imma do coffe stuff

# %% [markdown]
# ## Objectives

# %% [markdown]
# Be the best coffee there ever was

# %% [markdown]
# ## Code

# %% [markdown]
# ### Imports

# %% [markdown]
# Here we import our dependencies

# %%
import os
import pandas as pd
import zipfile
import urllib.request

# %% [markdown]
# ### Import Dataset

# %% [markdown]
# Download dataset from Kaggle. First we create the 'res' directory to store the downloaded file.

# %%
os.makedirs("res", exist_ok=True)
zip_url = "https://www.kaggle.com/api/v1/datasets/download/fatihb/coffee-quality-data-cqi"
full_route = os.path.join("res", "dataset.zip")
urllib.request.urlretrieve(zip_url, full_route)
# Out:
# ('res/dataset.zip', <http.client.HTTPMessage at 0x10753d2b0>)

# %% [markdown]
# Unzip downloaded file

# %%
file_route = os.path.join("res")
with zipfile.ZipFile(full_route, 'r') as zip:
    zip.extractall(file_route)

# %% [markdown]
# After unziping the file, we will obtain the csv file

# %%
dataset_url = os.path.join("res", "df_arabica_clean.csv")
coffee_dataset = pd.read_csv(dataset_url, sep=",")

# %% [markdown]
# Just to check everything is ok, we will check the first rows of the database and display sombe basic info.

# %%
display(coffee_dataset.head(3))
coffee_dataset.info()
# Out:
#    Unnamed: 0  ID Country of Origin                 Farm Name  \
# 0           0   0          Colombia          Finca El Paraiso
# 1           1   1            Taiwan  Royal Bean Geisha Estate
# 2           2   2              Laos        OKLAO coffee farms
#
#                                 Lot Number                           Mill  \
# 0                               CQU2022015               Finca El Paraiso
# 1  The 2022 Pacific Rim Coffee Summit,T037       Royal Bean Geisha Estate
# 2  The 2022 Pacific Rim Coffee Summit,LA01  oklao coffee processing plant
#
#   ICO Number                   Company   Altitude                Region  ...  \
# 0        NaN      Coffee Quality Union  1700-1930        Piendamo,Cauca  ...
# 1        NaN  Taiwan Coffee Laboratory       1200                Chiayi  ...
# 2        NaN  Taiwan Coffee Laboratory       1300  Laos Borofen Plateau  ...
#
#   Total Cup Points  Moisture Percentage Category One Defects Quakers  \
# ...
